# %%
# %autosave 0

import pandas as pd
from pandas import read_csv
import numpy as np
from mlflow import log_metric, log_param
# Out:
# Autosave disabled

# %%
trainfull_pred = read_csv( '../csv/trainfull_pred.csv')
Y_trainfull = read_csv( '../csv/Y_trainfull.csv')

# %%
Y_trainfull.shape
# Out:
# (8888, 1)

# %%
df = trainfull_pred.join(Y_trainfull)

# %%
df.columns = ('Pred_price', 'Real_price')

# %%
df['Absolute_error'] = abs(df['Pred_price']-df['Real_price'])

# %%
df['APE'] = (df['Absolute_error']/df['Real_price'])*100

# %%
df
# Out:
#        Pred_price  Real_price  Absolute_error          APE
# 0      512832.970     74000.0      438832.970   593.017527
# 1       41224.598    386900.0      345675.402    89.344896
# 2      276095.400    475000.0      198904.600    41.874653
# 3      512832.970     74000.0      438832.970   593.017527
# 4       41224.598    386900.0      345675.402    89.344896
# 5      276095.400    475000.0      198904.600    41.874653
# 6      512832.970     74000.0      438832.970   593.017527
# 7       41224.598    386900.0      345675.402    89.344896
# 8      276095.400    170500.0      105595.400    61.932786
# 9      267808.600    265000.0        2808.600     1.059849
# 10     261036.700    189000.0       72036.700    38.114656
# 11     411443.060    239000.0      172443.060    72.151908
# 12     224328.110    406175.0      181846.890    44.770577
# 13     359144.780   1396500.0     1037355.220    74.282508
# 14    1248091.800     89500.0     1158591.800  1294.515978
# 15      34082.870    824000.0      789917.130    95.863729
# 16    1074962.500    319000.0      755962.500   236.978840
# 17     413530.380    595000.0      181469.620    30.499096
# 18     578186.900     39000.0      539186.900  1382.530513
# 19     154707.980    299500.0      144792.020    48.344581
# 20     395163.660    628000.0      232836.340    37.075850
# 21     417911.940    287000.0      130911.940    45.613916
# 22     256168.310    525000.0      268831.690    51.206036
# 23     359144.780    253000.0      106144.780    41.954458
# 24      91338.805    299000.0      207661.195    69.451905
# 25     282597.800    175000.0      107597.800    61.484457
# 26     133824.700    485000.0      351175.300    72.407278
# 27     391358.380    185000.0      206358.380   111.545070
# 28     184413.390     39500.0      144913.390   366.869342
# 29     278392.600    453500.0      175107.400    38.612437
# ...           ...         ...             ...          ...
# 8859   665650.300    205000.0      460650.300   224.707463
# 8860   120068.900    243800.0      123731.100    50.751066
# 8861   250407.800     88000.0      162407.800   184.554318
# 8862   279577.970    268000.0       11577.970     4.320138
# 8863   134188.500    198000.0       63811.500    32.228030
# 8864   457275.530     49500.0      407775.530   823.788949
# 8865   119070.195    215000.0       95929.805    44.618514
# 8866   155850.580    109000.0       46850.580    42.982183
# 8867   176401.190     65000.0      111401.190   171.386446
# 8868   262519.100    272800.0       10280.900     3.768658
# 8869   183985.610    795000.0      611014.390    76.857156
# 8870   896126.900    287000.0      609126.900   212.239338
# 8871   294241.300     88000.0      206241.300   234.365114
# 8872    72105.620    490000.0      417894.380    85.284567
# 8873   472647.700    563000.0       90352.300    16.048366
# 8874   479333.750    645000.0      165666.250    25.684690
# 8875   540750.800    650000.0      109249.200    16.807569
# 8876   584276.940    876000.0      291723.060    33.301719
# 8877   787756.560    298760.0      488996.560   163.675378
# 8878   267037.660    277900.0       10862.340     3.908723
# 8879   330191.300    302000.0       28191.300     9.334868
# 8880   275620.700     39500.0      236120.700   597.773924
# 8881   168586.970    210000.0       41413.030    19.720490
# 8882   216501.140    358500.0      141998.860    39.609166
# 8883   306150.600    466400.0      160249.400    34.358791
# 8884   446454.380   1272000.0      825545.620    64.901385
# 8885   664995.250    475000.0      189995.250    39.999000
# 8886   512832.970     74000.0      438832.970   593.017527
# 8887    41224.598    386900.0      345675.402    89.344896
# 8888   276095.400         NaN             NaN          NaN
#
# [8889 rows x 4 columns]

# %% [markdown]
# # MAPE model avec remplacement par mediane dans colonne area_m2

# %%
print(round(df['APE'].mean(),2),"% ", round(df['APE'].max(),2),"% ", round(df['APE'].min(),2),"% ")
# Out:
# 182.8 %  22071.89 %  0.01 %

# %%
df.loc[df['APE']==df['APE'].max()]
# Out:
#       Pred_price  Real_price  Absolute_error           APE
# 2852   2882345.5     13000.0       2869345.5  22071.888462

# %%
df.loc[df['APE']>=100]
# Out:
#       Pred_price  Real_price  Absolute_error          APE
# 0      512832.97     74000.0       438832.97   593.017527
# 3      512832.97     74000.0       438832.97   593.017527
# 6      512832.97     74000.0       438832.97   593.017527
# 14    1248091.80     89500.0      1158591.80  1294.515978
# 16    1074962.50    319000.0       755962.50   236.978840
# 18     578186.90     39000.0       539186.90  1382.530513
# 27     391358.38    185000.0       206358.38   111.545070
# 28     184413.39     39500.0       144913.39   366.869342
# 36     308340.03    105000.0       203340.03   193.657171
# 43     398844.97    131000.0       267844.97   204.461809
# 47     487767.97     39500.0       448267.97  1134.855620
# 49     552539.06    220000.0       332539.06   151.154118
# 52     320065.84    150000.0       170065.84   113.377227
# 54    1348765.80     16000.0      1332765.80  8329.786250
# 57     578186.90    246500.0       331686.90   134.558580
# 60     409460.62    151200.0       258260.62   170.807288
# 66     404518.88    190800.0       213718.88   112.011992
# 72     744370.60    286200.0       458170.60   160.087561
# 74     219210.69     90950.0       128260.69   141.023299
# 76     367589.40    175000.0       192589.40   110.051086
# 78     497308.10     55000.0       442308.10   804.196545
# 81     437754.10     25724.0       412030.10  1601.734178
# 83     474124.28    139000.0       335124.28   241.096604
# 91     809253.94    246000.0       563253.94   228.965016
# 97     232623.27     77000.0       155623.27   202.108143
# 103   1948388.00    138900.0      1809488.00  1302.727142
# 107    535560.00    259700.0       275860.00   106.222564
# 109    524117.47     37000.0       487117.47  1316.533703
# 119    344389.62    137800.0       206589.62   149.919898
# 124    980029.00     43500.0       936529.00  2152.940230
# ...          ...         ...             ...          ...
# 8798   746140.80     76300.0       669840.80   877.904063
# 8804   311232.70    146000.0       165232.70   113.173082
# 8806   153005.67     14000.0       139005.67   992.897643
# 8810  1456463.00     44000.0      1412463.00  3210.143182
# 8814   376007.06     75000.0       301007.06   401.342747
# 8817   456756.28    180200.0       276556.28   153.471853
# 8819   248128.80     60000.0       188128.80   313.548000
# 8824   382973.53    180200.0       202773.53   112.526931
# 8826   175926.72     64800.0       111126.72   171.491852
# 8829   362253.20    180200.0       182053.20   101.028413
# 8831   400764.28    185500.0       215264.28   116.045434
# 8835   877981.70    265000.0       612981.70   231.313849
# 8837   237112.48     77000.0       160112.48   207.938286
# 8841   529950.20     99000.0       430950.20   435.303232
# 8842   261313.75     69000.0       192313.75   278.715580
# 8844   554504.70     51350.0       503154.70   979.853359
# 8847   549165.40     80800.0       468365.40   579.660149
# 8848   109781.05     33200.0        76581.05   230.665813
# 8852   477678.60    151000.0       326678.60   216.343444
# 8855   173131.88     79000.0        94131.88   119.154278
# 8857   482647.00    162000.0       320647.00   197.930247
# 8859   665650.30    205000.0       460650.30   224.707463
# 8861   250407.80     88000.0       162407.80   184.554318
# 8864   457275.53     49500.0       407775.53   823.788949
# 8867   176401.19     65000.0       111401.19   171.386446
# 8870   896126.90    287000.0       609126.90   212.239338
# 8871   294241.30     88000.0       206241.30   234.365114
# 8877   787756.56    298760.0       488996.56   163.675378
# 8880   275620.70     39500.0       236120.70   597.773924
# 8886   512832.97     74000.0       438832.97   593.017527
#
# [2649 rows x 4 columns]

# %% [markdown]
# # Enregistrement des résultats si voulus (mettre log = True)
# -> accessible sous localhost:3000

# %%
log_metric("MAPE sur train", round(df['APE'].median(),2))
# Out:
# /opt/conda/lib/python3.7/site-packages/py4j/java_collections.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import (
