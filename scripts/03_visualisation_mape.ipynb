# %%
# %autosave 0

import pandas as pd
from pandas import read_csv
import numpy as np
from mlflow import log_metric, log_param
# Out:
# Autosave disabled

# %%
trainfull_pred = read_csv( '../csv/trainfull_pred.csv')
Y_trainfull = read_csv( '../csv/Y_trainfull.csv')

# %%
Y_trainfull.shape
# Out:
# (4799, 1)

# %%
df = trainfull_pred.join(Y_trainfull)

# %%
df.columns = ('Pred_price', 'Real_price')

# %%
df['Absolute_error'] = abs(df['Pred_price']-df['Real_price'])

# %%
df['APE'] = (df['Absolute_error']/df['Real_price'])*100

# %%
df
# Out:
#        Pred_price  Real_price  Absolute_error          APE
# 0      279070.220    199300.0       79770.220    40.025198
# 1      503029.440    143700.0      359329.440   250.055282
# 2      194078.400     74990.0      119088.400   158.805707
# 3      274482.380    130000.0      144482.380   111.140292
# 4      231024.920    114990.0      116034.920   100.908705
# 5      129014.420    183260.0       54245.580    29.600338
# 6      165001.250    172640.0        7638.750     4.424670
# 7      325726.880     69000.0      256726.880   372.067942
# 8      172806.550    197700.0       24893.450    12.591528
# 9      300267.100    233200.0       67067.100    28.759477
# 10     268830.100    449000.0      180169.900    40.126927
# 11     490747.340    109140.0      381607.340   349.649386
# 12     222721.700    268000.0       45278.300    16.894888
# 13     319380.250    250000.0       69380.250    27.752100
# 14     177618.830    735000.0      557381.170    75.834173
# 15     854584.500    325000.0      529584.500   162.949077
# 16     424348.030    880000.0      455651.970    51.778633
# 17     805445.500    630000.0      175445.500    27.848492
# 18     642197.060    145990.0      496207.060   339.891130
# 19     222779.190    276500.0       53720.810    19.428864
# 20     611062.250    543325.0       67737.250    12.467170
# 21     472641.340    630000.0      157358.660    24.977565
# 22     550451.750    138000.0      412451.750   298.878080
# 23     333341.800    331000.0        2341.800     0.707492
# 24     375589.060    140000.0      235589.060   168.277900
# 25     287456.100    348000.0       60543.900    17.397672
# 26     448450.250    178500.0      269950.250   151.232633
# 27     270249.970    179000.0       91249.970    50.977637
# 28     303354.300    387000.0       83645.700    21.613876
# 29     224792.420    140000.0       84792.420    60.566014
# ...           ...         ...             ...          ...
# 4770   958897.440   2400000.0     1441102.560    60.045940
# 4771  2430341.500    278000.0     2152341.500   774.223561
# 4772   500357.100     13000.0      487357.100  3748.900769
# 4773    46014.055    285500.0      239485.945    83.882993
# 4774   324836.160     55000.0      269836.160   490.611200
# 4775   158266.230   5900000.0     5741733.770    97.317522
# 4776  5212468.500    206700.0     5005768.500  2421.755443
# 4777   156560.250    118000.0       38560.250    32.678178
# 4778   204635.230    750000.0      545364.770    72.715303
# 4779   951707.000    439000.0      512707.000   116.789749
# 4780   400349.470    222600.0      177749.470    79.851514
# 4781   189184.380    618000.0      428815.620    69.387641
# 4782   605584.940    265000.0      340584.940   128.522619
# 4783   307286.340   1484000.0     1176713.660    79.293373
# 4784  1655576.200    107000.0     1548576.200  1447.267477
# 4785   137263.980     64000.0       73263.980   114.474969
# 4786   197486.670    252000.0       54513.330    21.632274
# 4787   279560.280    193860.0       85700.280    44.207304
# 4788   343401.200   1430000.0     1086598.800    75.985930
# 4789  1275109.900    697000.0      578109.900    82.942597
# 4790   528891.940    358700.0      170191.940    47.446875
# 4791   329186.160    335000.0        5813.840     1.735475
# 4792   705839.250     81750.0      624089.250   763.411927
# 4793   136013.400    428000.0      291986.600    68.221168
# 4794   651364.940    172640.0      478724.940   277.296652
# 4795   214656.900     48000.0      166656.900   347.201875
# 4796   164832.700    164300.0         532.700     0.324224
# 4797   174621.620     63000.0      111621.620   177.177175
# 4798   252397.530    148936.0      103461.530    69.467107
# 4799   136483.770         NaN             NaN          NaN
#
# [4800 rows x 4 columns]

# %% [markdown]
# # MAPE model avec remplacement par mediane dans colonne area_m2

# %%
print(round(df['APE'].mean(),2),"% ", round(df['APE'].max(),2),"% ", round(df['APE'].min(),2),"% ")
# Out:
# 166.3 %  11418.01 %  0.04 %

# %%
df.loc[df['APE']==df['APE'].max()]
# Out:
#       Pred_price  Real_price  Absolute_error           APE
# 3614   3052271.8     26500.0       3025771.8  11418.006792

# %%
df.loc[df['APE']>=100]
# Out:
#       Pred_price  Real_price  Absolute_error          APE
# 1      503029.44    143700.0       359329.44   250.055282
# 2      194078.40     74990.0       119088.40   158.805707
# 3      274482.38    130000.0       144482.38   111.140292
# 4      231024.92    114990.0       116034.92   100.908705
# 7      325726.88     69000.0       256726.88   372.067942
# 11     490747.34    109140.0       381607.34   349.649386
# 15     854584.50    325000.0       529584.50   162.949077
# 18     642197.06    145990.0       496207.06   339.891130
# 22     550451.75    138000.0       412451.75   298.878080
# 24     375589.06    140000.0       235589.06   168.277900
# 26     448450.25    178500.0       269950.25   151.232633
# 33     607351.30    199800.0       407551.30   203.979630
# 35     393079.72    178500.0       214579.72   120.212728
# 38     536294.90    187500.0       348794.90   186.023947
# 40     549099.90    212000.0       337099.90   159.009387
# 43    1089188.20    409999.0       679189.20   165.656306
# 45     551873.00    207000.0       344873.00   166.605314
# 49     352608.94    145000.0       207608.94   143.178579
# 52     421422.25    145000.0       276422.25   190.636034
# 55     465913.53    158000.0       307913.53   194.881981
# 61     536753.90    235000.0       301753.90   128.405915
# 64     342848.40    160500.0       182348.40   113.612710
# 68     752489.10    329000.0       423489.10   128.720091
# 74     569239.20    105000.0       464239.20   442.132571
# 77     856762.50    275600.0       581162.50   210.871734
# 80     509833.38    173000.0       336833.38   194.701376
# 90     390908.10    152000.0       238908.10   157.176382
# 101    752937.06    123000.0       629937.06   512.143951
# 105   1091961.40     89500.0      1002461.40  1120.068603
# 107   1061600.00    319000.0       742600.00   232.789969
# ...          ...         ...             ...          ...
# 4699   874960.60    299900.0       575060.60   191.750784
# 4701   451266.12    139600.0       311666.12   223.256533
# 4703   233916.77     39000.0       194916.77   499.786590
# 4706   555293.50    122000.0       433293.50   355.158607
# 4715   516383.06    156600.0       359783.06   229.746526
# 4717   387639.12    159000.0       228639.12   143.798189
# 4719   357507.28     85000.0       272507.28   320.596800
# 4722   242902.81     44000.0       198902.81   452.051841
# 4725   305496.47    100990.0       204506.47   202.501703
# 4737   240456.39     77000.0       163456.39   212.281026
# 4739   409130.78    183260.0       225870.78   123.251544
# 4742   451325.38    180200.0       271125.38   150.458036
# 4745   199549.73     86400.0       113149.73   130.960336
# 4748   232805.89     27300.0       205505.89   752.768828
# 4756   953296.06     80000.0       873296.06  1091.620075
# 4759   618549.56    264000.0       354549.56   134.299076
# 4760   301772.20     67000.0       234772.20   350.406269
# 4764   369656.72    180000.0       189656.72   105.364844
# 4771  2430341.50    278000.0      2152341.50   774.223561
# 4772   500357.10     13000.0       487357.10  3748.900769
# 4774   324836.16     55000.0       269836.16   490.611200
# 4776  5212468.50    206700.0      5005768.50  2421.755443
# 4779   951707.00    439000.0       512707.00   116.789749
# 4782   605584.94    265000.0       340584.94   128.522619
# 4784  1655576.20    107000.0      1548576.20  1447.267477
# 4785   137263.98     64000.0        73263.98   114.474969
# 4792   705839.25     81750.0       624089.25   763.411927
# 4794   651364.94    172640.0       478724.94   277.296652
# 4795   214656.90     48000.0       166656.90   347.201875
# 4797   174621.62     63000.0       111621.62   177.177175
#
# [1352 rows x 4 columns]

# %% [markdown]
# # Enregistrement des résultats si voulus (mettre log = True)
# -> accessible sous localhost:3000

# %%
log_metric("MAPE sur train", round(df['APE'].median(),2))
# Out:
# /opt/conda/lib/python3.7/site-packages/py4j/java_collections.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import (
