# %%
# %autosave 0
import scipy
import numpy 
import matplotlib
import pandas as pd
import numpy as np 
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import scatter_matrix 
from numpy import set_printoptions 
set_printoptions(precision=0)
pd.set_option("display.precision", 2)
pd.option_context('display.float_format', '{:0f}'.format);
# Out:
# Autosave disabled

# %%
# Importation du fichier csv dans un dataframe
# df_train_full = read_csv( './dataset-template.csv')
df_train_full = read_csv( './csv/realstate-data.csv' )

# %%
# peek
df_train_full.head(10)
# Out:
#                                     ref                   city  \
# 0      /fr/properties/30731a-133656.htm           Saint-Maurin
# 1  /fr/properties/88486a-95148cj265.htm     Castelnau-de-Médoc
# 2        /fr/properties/44945a-m728.htm            Peyrehorade
# 3        /fr/properties/32488a-2534.htm               Bourlens
# 4        /fr/properties/32488a-2557.htm       Monsempron-Libos
# 5        /fr/properties/44945a-a403.htm               Biarritz
# 6       /fr/properties/7140a-4262jp.htm               Bergerac
# 7   /fr/properties/52956a-128mx2211.htm  Saint-Germain-et-Mons
# 8       /fr/properties/179101a-3006.htm        Bénesse-Maremne
# 9    /fr/properties/33922a-145mx977.htm     Villeneuve-sur-Lot
#
#                  county   district  area_m2  ground_m2  nb_room  nb_bedroom  \
# 0        Lot-et-Garonne  Aquitaine    100.0        NaN      5.0         3.0
# 1               Gironde  Aquitaine    328.0     3700.0      9.0         4.0
# 2                Landes  Aquitaine    814.0   100000.0     19.0         8.0
# 3        Lot-et-Garonne  Aquitaine    406.0    13200.0     14.0        10.0
# 4        Lot-et-Garonne  Aquitaine     99.0       35.0      4.0         3.0
# 5  Pyrénées-Atlantiques  Aquitaine     75.0        NaN      3.0         2.0
# 6              Dordogne  Aquitaine    165.0     2190.0      6.0         4.0
# 7              Dordogne  Aquitaine    132.0     1441.0      5.0         4.0
# 8                Landes  Aquitaine    107.0      567.0      4.0         3.0
# 9        Lot-et-Garonne  Aquitaine    170.0    14600.0      6.0         4.0
#
#    pool cellar garage   output
# 0   NaN    NaN    NaN   210000
# 1   NaN    NaN   True   840000
# 2  True   True    NaN  1950000
# 3   NaN    NaN    NaN   975200
# 4   NaN    NaN    NaN   101520
# 5   NaN    NaN    NaN   650000
# 6   NaN    NaN   True   318000
# 7   NaN    NaN    NaN   205000
# 8   NaN    NaN   True   355000
# 9   NaN   True    NaN   270000

# %%
# description
df_train_full.describe()
# Out:
#         area_m2  ground_m2  nb_room  nb_bedroom    output
# count   6880.00   5.74e+03  6311.00     6221.00  7.20e+03
# mean     313.85   2.45e+04     7.10        4.52  4.53e+05
# std     1052.33   3.63e+05     3.77        2.34  6.30e+05
# min        1.00   1.00e+00     2.00        2.00  8.00e+03
# 25%      125.00   1.11e+03     5.00        3.00  1.98e+05
# 50%      180.00   3.00e+03     6.00        4.00  3.11e+05
# 75%      280.00   9.48e+03     8.00        5.00  4.98e+05
# max    29760.00   2.69e+07    70.00       50.00  1.60e+07

# %%
# effectif des classes
df_train_full.groupby('city').size()
# Out:
# city
# Abidos                   2
# Abjat-sur-Bandiat        2
# Accous                   3
# Agen                   137
# Agmé                     1
#                       ...
# Virsac                   1
# Vitrac                   3
# Vélines                 15
# Vézac                    1
# Ygos-Saint-Saturnin      2
# Length: 1078, dtype: int64

# %%
# corrélation
correlations = df_train_full.corr(method='pearson') 
print(correlations)
# Out:
#             area_m2  ground_m2  nb_room  nb_bedroom  output
# area_m2        1.00       0.01     0.55        0.52    0.07
# ground_m2      0.01       1.00     0.06        0.07    0.10
# nb_room        0.55       0.06     1.00        0.86    0.37
# nb_bedroom     0.52       0.07     0.86        1.00    0.38
# output         0.07       0.10     0.37        0.38    1.00

# %%
# erreur
skew = df_train_full.skew() 
print(skew)
# Out:
# area_m2       17.39
# ground_m2     70.58
# nb_room        2.69
# nb_bedroom     4.04
# output         9.92
# dtype: float64

# %%
# histogramme
df_train_full.hist(figsize=(10,10))
pyplot.show()

# %%
# density plot
df_train_full.plot(kind='density', subplots=True, layout=(8,6), sharex=False, figsize=(15,15)) 
pyplot.show()

# %%
# boxplot
df_train_full.plot(kind='box', subplots=True, layout=(8,6), sharex=False, sharey=False, figsize=(15,15)) 
pyplot.show()

# %%
# correlation matrix
correlations = df_train_full.corr() 
fig = pyplot.figure(figsize=(6,6)) 
ax = fig.add_subplot(111) 
cax = ax.matshow(correlations, vmin=-1, vmax=1) 
fig.colorbar(cax) 
pyplot.show()

# %%
# nuage de point
scatter_matrix(df_train_full, figsize=(7,7)) 
pyplot.show()
